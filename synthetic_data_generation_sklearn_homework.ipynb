# %% [markdown]
# <hr style="border: 6px solid#003262;" />
#
# <div align="center">
#     <img src="assets/content/images/thumbnail.png" align="center" width="20%">
# </div>
#
# <br>
#
# # SYNTHETIC DATA GENERATION - SKLEARN HOMEWORK
#
# <br>
#
# **About:** Exercises using scikit-learn dataset generators to create controlled synthetic datasets for regression, classification, and clustering.
#
# **Learning Goals:** Control noise in make_regression and observe its effect on R2; tune class_sep in make_classification and observe its effect on accuracy; generate and visualize a clustering problem with make_blobs.
#
# **Keywords:** synthetic data, sklearn, make_regression, make_classification, make_blobs
#
# **Prerequisite Knowledge:** (1) Python, (2) NumPy, (3) Matplotlib, (4) `02_synthetic_data_generation_sklearn.ipynb`
#
# **Target User:** Data science students who have completed the companion lesson notebook

# %% [markdown]
# <hr style="border: 4px solid#003262;" />
#
# <a name='Part_table_contents' id="Part_table_contents"></a>

# %% [markdown]
# #### CONTENTS
#
# > #### [PART 1: REGRESSION WITH NOISE](#Part_1)
# > #### [PART 2: CLASSIFICATION WITH SEPARATION](#Part_2)
# > #### [PART 3: GENERALIZATION](#Part_3)
#
# <br>

# %%
# All imports for this homework live in this single cell.
import numpy as np
import matplotlib.pyplot as plt

# TODO: verify against current sklearn docs
from sklearn.datasets import make_regression, make_classification, make_blobs, make_moons
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import r2_score, accuracy_score

# %% [markdown]
# <a id='Part_1'></a>
#
# <hr style="border: 2px solid#003262;" />
#
# #### PART 1
#
# ## **REGRESSION** WITH CONTROLLED **NOISE**
#
# The lesson introduced `make_regression` as a way to construct a supervised regression problem where you know the underlying linear structure. The one knob that matters most for the difficulty of the learning problem is `noise`, the standard deviation of Gaussian noise added to the target. In this part you will build two datasets that share every parameter except noise, then compare how well a linear model can recover the signal in each.
#
# ___
#
# **Note:** Sources consulted for this part: sklearn [`make_regression`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_regression.html) and [`LinearRegression`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html) documentation.
#
# ___

# %% [markdown]
# <a id='Part_1_1'></a>
#
# <hr style="border: 1px solid#003262;" />
#
# #### PART 1.1: GENERATE LOW AND HIGH NOISE DATASETS
#
# Generate two regression datasets with the same shape and random state, but different `noise` values. Use `noise=5.0` for the low noise dataset and `noise=50.0` for the high noise dataset. Store them as `(X_low, y_low)` and `(X_high, y_high)`.

# %%
n_samples = 200        # don't change these lines
n_features = 5         # don't change these lines
random_state = 0       # don't change these lines
noise_low = 5.0        # don't change these lines
noise_high = 50.0      # don't change these lines

### YOUR CODE HERE ###

# TODO: verify against current sklearn docs
X_low, y_low = ...
X_high, y_high = ...

#print(X_low.shape, X_high.shape)
#print("y_low std:", y_low.std(), " y_high std:", y_high.std())

# %% [markdown]
# <a id='Part_1_2'></a>
#
# <hr style="border: 1px solid#003262;" />
#
# #### PART 1.2: FIT LINEAR REGRESSION AND COMPARE R2
#
# For each dataset, do a 75/25 train/test split, fit a `LinearRegression`, predict on the test set, and compute the R2 score. Store the two scores in `r2_low` and `r2_high`.

# %%
test_size = 0.25       # don't change these lines
split_seed = 1         # don't change these lines

### YOUR CODE HERE ###

# Low noise
X_train, X_test, y_train, y_test = ...
model_low = LinearRegression()
...
r2_low = ...

# High noise
X_train, X_test, y_train, y_test = ...
model_high = LinearRegression()
...
r2_high = ...

#print(f"R2 (low noise):  {r2_low:.3f}")
#print(f"R2 (high noise): {r2_high:.3f}")

# %% [markdown]
# <br>
#
# **Interpretation**
#
# Explain in two or three sentences why R2 decreases as noise increases, even though the underlying linear signal in the data is identical in both cases. Refer to how R2 is defined as a fraction of variance explained.

# %% [markdown]
# *ANSWER HERE*

# %% [markdown]
# <!--Navigate back to table of contents-->
# <div align="left" style="text-align: left; background-color:#003262;">
#     <span>
#         <hr style="border: 8px solid#003262;" />
#         <a style="color:#FFFFFF; background-color:#003262; border:1px solid #FFFFFF; border-color:#FFFFFF;border-radius:0px;border-width:0px;display:inline-block;font-family:arial,helvetica,sans-serif;font-size:24px;letter-spacing:0px;line-height:20px;padding:24px 40px;text-align:left;text-decoration:none; align:left">
#             <strong>CONCEPT</strong> CHECK
#         </a>
#     </span>
# </div>
# <!-------------------------------------->
#
# > **If you doubled `noise` again to 100.0 while keeping every other parameter fixed, would you expect R2 to keep dropping linearly with noise, or level off? Support your answer with a short experiment.**
#
# <br>
#
# ```python
# # Sweep noise across [5, 25, 50, 100, 200], regenerate the dataset each time,
# # fit a LinearRegression, and plot R2 vs noise on a log-x axis.
# ```
#
# <hr style="border: 2px solid#003262;" />

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# *ANSWER HERE*

# %% [markdown]
# <!--Navigate back to table of contents-->
# <div alig="right" style="text-align: right">
#     <span>
#         <a style="color:#FFFFFF; background-color:#003262; border:1px solid #FFFFFF; border-color:#FFFFFF;border-radius:5px;border-width:0px;display:inline-block;font-family:arial,helvetica,sans-serif;font-size:10px;letter-spacing:0px;line-height:10px;padding:10px 20px;text-align:center;text-decoration:none; align:center" href="#Part_table_contents" name="Table of Contents"  id="Part_table_contents">
#             Table of Contents
#         </a>
#     </span>
# </div>
# <!-------------------------------------->

# %% [markdown]
# <a id='Part_2'></a>
#
# <hr style="border: 2px solid#003262;" />
#
# #### PART 2
#
# ## **CLASSIFICATION** WITH CONTROLLED **SEPARATION**
#
# `make_classification` gives you a `class_sep` knob that scales the distance between class clusters in feature space. When `class_sep` is small the classes overlap heavily and no linear model can cleanly separate them; when it is large the classes sit far apart and even a weak model achieves near-perfect accuracy. In this part you will observe both regimes with the same architecture.
#
# ___
#
# **Note:** Sources consulted for this part: sklearn [`make_classification`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html).
#
# ___

# %% [markdown]
# <a id='Part_2_1'></a>
#
# <hr style="border: 1px solid#003262;" />
#
# #### PART 2.1: GENERATE TWO CLASSIFICATION DATASETS
#
# Create two two-feature, two-class datasets: one with `class_sep=0.5` (overlapping) and one with `class_sep=3.0` (well separated). Everything else should match.

# %%
n_samples = 400        # don't change these lines
random_state = 0       # don't change these lines

### YOUR CODE HERE ###

# TODO: verify against current sklearn docs
# Use n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1
X_hard, y_hard = ...
X_easy, y_easy = ...

#print(X_hard.shape, X_easy.shape)

# %% [markdown]
# <a id='Part_2_2'></a>
#
# <hr style="border: 1px solid#003262;" />
#
# #### PART 2.2: VISUALIZE THE TWO DATASETS
#
# Plot the two datasets side by side. Color points by class. This makes the geometric effect of `class_sep` visible before you ever fit a model.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

### YOUR CODE HERE ###
# Left: scatter X_hard colored by y_hard on axes[0]
...

# Right: scatter X_easy colored by y_easy on axes[1]
...

axes[0].set_title("class_sep = 0.5")
axes[1].set_title("class_sep = 3.0")
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id='Part_2_3'></a>
#
# <hr style="border: 1px solid#003262;" />
#
# #### PART 2.3: FIT LOGISTIC REGRESSION AND COMPARE
#
# Fit a `LogisticRegression` on each dataset with a 75/25 split and record the test accuracy in `acc_hard` and `acc_easy`.

# %%
test_size = 0.25       # don't change these lines
split_seed = 2         # don't change these lines

### YOUR CODE HERE ###

# Hard case
X_train, X_test, y_train, y_test = ...
# TODO: verify against current sklearn docs
model_hard = LogisticRegression(max_iter=1000)
...
acc_hard = ...

# Easy case
X_train, X_test, y_train, y_test = ...
model_easy = LogisticRegression(max_iter=1000)
...
acc_easy = ...

#print(f"Accuracy (class_sep=0.5): {acc_hard:.3f}")
#print(f"Accuracy (class_sep=3.0): {acc_easy:.3f}")

# %% [markdown]
# <br>
#
# **Interpretation**
#
# As `class_sep` approaches zero, the two class distributions overlap almost completely. Describe what happens to the decision boundary a Logistic Regression would draw in that limit, and what test accuracy you would expect on a balanced two class problem.

# %% [markdown]
# *ANSWER HERE*

# %% [markdown]
# <!--Navigate back to table of contents-->
# <div alig="right" style="text-align: right">
#     <span>
#         <a style="color:#FFFFFF; background-color:#003262; border:1px solid #FFFFFF; border-color:#FFFFFF;border-radius:5px;border-width:0px;display:inline-block;font-family:arial,helvetica,sans-serif;font-size:10px;letter-spacing:0px;line-height:10px;padding:10px 20px;text-align:center;text-decoration:none; align:center" href="#Part_table_contents" name="Table of Contents"  id="Part_table_contents">
#             Table of Contents
#         </a>
#     </span>
# </div>
# <!-------------------------------------->

# %% [markdown]
# <a id='Part_3'></a>
#
# <hr style="border: 2px solid#003262;" />
#
# #### PART 3
#
# ## **GENERALIZATION** WITH NON LINEAR **MOONS**
#
# `make_regression`, `make_classification`, and `make_blobs` all produce geometries a linear model can handle when the noise or overlap is not too bad. `make_moons` breaks that assumption on purpose: it generates two interleaved half-circles, which are not linearly separable no matter how much data you draw. This is the transfer test: apply the same fit-and-score workflow to a dataset shape you have not seen before, and diagnose why the linear model fails.
#
# ___
#
# **Note:** Sources consulted for this part: sklearn [`make_moons`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html).
#
# ___

# %% [markdown]
# <a id='Part_3_1'></a>
#
# <hr style="border: 1px solid#003262;" />
#
# #### PART 3.1: GENERATE AND VISUALIZE MOONS
#
# Generate 200 moon-shaped samples with `noise=0.1` and plot them, coloring by class. Store the result in `X_moons, y_moons`.

# %%
n_samples = 200        # don't change these lines
moon_noise = 0.1       # don't change these lines
random_state = 0       # don't change these lines

### YOUR CODE HERE ###

# TODO: verify against current sklearn docs
X_moons, y_moons = ...

plt.figure(figsize=(5, 4))
# Scatter X_moons colored by y_moons
...
plt.title("make_moons, noise=0.1")
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id='Part_3_2'></a>
#
# <hr style="border: 1px solid#003262;" />
#
# #### PART 3.2: FIT A LINEAR CLASSIFIER
#
# Fit a `LogisticRegression` on a 75/25 split of the moons data and report the test accuracy in `acc_moons`.

# %%
test_size = 0.25       # don't change these lines
split_seed = 3         # don't change these lines

### YOUR CODE HERE ###

X_train, X_test, y_train, y_test = ...
# TODO: verify against current sklearn docs
moon_model = LogisticRegression(max_iter=1000)
...
acc_moons = ...

#print(f"Accuracy (moons, linear model): {acc_moons:.3f}")

# %% [markdown]
# <br>
#
# **Interpretation**
#
# Look at your moons scatter plot and your accuracy score together. Explain whether a straight line boundary is adequate for this dataset, and name one class of model that would do better here without changing the data.

# %% [markdown]
# *ANSWER HERE*
